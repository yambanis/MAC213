# %% [markdown]
# # Introdução ao Python para análise de dados
#
# Neste tutorial, iremos cobrir conceitos básicos de python e alguns de seus pacotes úteis para análise de dados.
#
# ## O que é Python?
#
# [Python](https://www.python.org/) e uma das linguagens de programacao mais utilizadas atualmente. Ele e conhecida por ser de fácil legibilidade.
#
# Este tutorial não tem por objetivo ser um curso completo de Python. Iremos utilizá-la apenas como uma ferramenta para analisarmos dados e vamos cobrir apenas aspectos que forem se mostrando necessários.
#
# Existem muitos [materiais](https://www.python.org/about/gettingstarted/) [excelentes](https://www.codecademy.com/learn/learn-python) [na internet](https://www.tutorialspoint.com/python/) e, se voce se interessar mais por Python, recomendamos que consulte algum deles.

# %% [markdown]
# ## Variáveis
#
# Programar em Python pode ser bastante simples.
#
# Vamos começar declarando uma variável.
#
# [Variaveis](https://pt.wikipedia.org/wiki/Vari%C3%A1vel_(programa%C3%A7%C3%A3o)) e um nome que, em computacao, se refere a um local onde iremos guardar informações.
#
# Usando algumas informacoes que coletamos [neste tutorial](https://github.com/yambanis/MAC213/blob/master/Excel/Tutoriais/Tutorial%202%20-%20Funcoes.md), vamos criar uma variavel para guardar o numero de matriculados no distrito de AGUA RASA.

# %%
aguaRasa = 0

# %% [markdown]
# Pronto! Sua variável já está criada! Simples não?
#
# Mas nossa variável aguaRasa ainda não possui nenhuma informação dentro dela. Para isso guardar o dado em uma variável, usamos o comando de [atribuicao](https://pt.wikipedia.org/wiki/Atribui%C3%A7%C3%A3o_(computa%C3%A7%C3%A3o)), usando o símbolo de igual.

# %%
aguaRasa = 5578

# %% [markdown]
# Dessa forma, nossa variável aguaRasa agora guarda dentro de si o valor 5578.

# %% [markdown]
# ## Funções
#
# Utilizando [funções](https://www.cs.utah.edu/~germain/PPS/Topics/functions.html) somos capazes de realizar tarefas que alguém já programou previamente, sem saber como elas funcionam!
#
# Vamos agora imprimir(mostrar na tela) o valor que guardamos na nossa variável aguaRasa. Muitas coisas estão envolvidas neste processo, como acesso à memória, controle de entrada e saída, mas utilizando a função **print()** não é necessário que saibamos fazer nenhuma dessas coisas. Basta escrever:

# %%
print(aguaRasa)
# Out:
# 5578

# %% [markdown]
# Clique no _play_ do notebook e o valor da variável aguaRasa irá aparecer na tela.
#
# Geralmente as funções tem um nome e argumentos que elas recebem. Neste caso, o nome da nossa função é _print_ e o argumento, ou o que ela recebe dentro dos seus parênteses, e o que desejamos imprimir, nesse caso a variável aguaRasa.
#
# Se quisermos imprimir a palavra Agua Rasa ao invés da variável, basta escrevermos o que desejamos imprimir entre parênteses:

# %%
print("Numero de matriculados no distrito de Agua rasa:")
print(aguaRasa)
# Out:
# Numero de matriculados no distrito de Agua rasa:
# 5578

# %% [markdown]
# ## Operações simples
#
# Para realizarmos operações simples em Python, basta escrevê-las de forma bastante intuitiva.
#
# Vamos Realizar a soma dos valores dos distritos de AGUA RASA, ALTO DE PINHEIROS E ANHANGUERA.
#
# Vamos, primeiro armazenar esses dados em 3 variáveis:

# %%
aRasa = 5578
aPinheiros = 434
anhanguera = 8813

# %% [markdown]
# Agora vamos criar uma variável total que será a soma das três. Basta escrever:

# %%
total = aRasa + aPinheiros + anhanguera

# %% [markdown]
# Finalmente, vamos imprimir esse valor na tela:

# %%
print(total)
# Out:
# 14825

# %% [markdown]
# Para realizar outras operações matemáticas elementares, como subtracao, multiplicacao e divisao, basta escrever de modo natural, assim como fizemos para a soma.

# %% [markdown]
# # Bibliotecas
#
# Bibliotecas(ou _libraries_) são conjuntos de rotinas que poderemos utilizar em nosso programa. O python já vem com algumas por padrão, por exemplo o print que utilizamos no exemplo anterior, mas podemos ainda importar outras bibliotecas diferentes.

# %% [markdown]
# ## Pacote Pandas
#
# O pandas ou [Python Data Analysis Library](https://pandas.pydata.org/) e uma biblioteca muito util, que irá nos fornecer diversas ferramentas para análise de dados.
#
# Para utiliza-la, escrevemos no início do nosso código no notebook:

# %%
import pandas as pd

# %% [markdown]
# Clicamos em _play_ para realizar a importação da biblioteca.
#
# O comando import realiza a importação enquanto o _as_ da um "apelido" para a nossa biblioteca, para que não tenhamos que escrever seu nome inteiro no nosso código.
#
# Nesse caso, importamos a biblioteca pandas e iremos nos referenciar a ela com _pd_ em nosso código.

# %% [markdown]
# ## Lendo CSV com pandas
#
# Primeiramente vamos baixar um arquivo csv para utilizarmos.
# Entre na [pagina de dados abertos prefeitura](http://dados.prefeitura.sp.gov.br/pt_PT/dataset/rendimento-e-movimento-escolar-ensino-fundamental) e faca o download do arquivo _Rendimento e Movimento Escolar - 2000 a 2015_ clicando em Explorar->Transferir.
#
#
# Agora, vamos realizar a leitura desse arquivo CSV com o comando pd.read_csv.
#
# Coloque o arquivo na mesma pasta do seu notebook.
#
# Para tal, vamos criar uma variavel df e salvar a leitura nela:

# %%
df = pd.read_csv('idadeserieneeracadez17.csv' , 
                 sep = ";", encoding = 'latin-1', header = 0)
df
# Out:
#        DRE  CODESC     TIPOESC                                    NOMESC  \
# 0       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 1       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 2       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 3       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 4       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 5       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 6       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 7       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 8       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 9       BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 10      BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# 11      BT     191        EMEF                 ALIPIO CORREA NETO, PROF.
# ...

# %% [markdown]
# Atraves desse comando, a nossa variavel df ira ler e armazenar o arquivo csv. O argumento sep indica que o ponto e virgula e o elemento de separacao do nosso csv, em enconding utilizamos latin-1 para indicar a codificacao de simbolos utilizados no portuges, como cedilha e indicamos o header igual a zero, mostrando que a informacao do header de cada coluna esta na linha 0.
#
# Se digitarmos:

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# sera possivel constatar que df e uma variavel do tipo pandas.core.frame.DataFrame.
#
# O [DataFrame](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) e uma estrutura tabular do Pandas, que possui diversas funcoes ja implementadas. Nossa tabela(ou csv) esta guardada dentro dela e iremos manipula-la para extair as informacoes que desejamos.

# %% [markdown]
# ## Analise de distribuicao de Sexo por atividadde
#
# No data frame anterior, importamos o csv em sua totalidade. Se quisermos importar algumas colunas especificas, podemos utilizar
# o argumento 'usecols'. Assim, podemos definir quais linhas queremos utilizar.
# Vamos fazer uma analise da distribuicao dos sexos entre as atividades realizadas nas instituicoes.

# %%
df = pd.read_csv('idadeserieneeracadez17.csv' , 
        sep = ";", encoding = 'latin-1', header = 0, usecols = ['DESCSERIE', 'SEXO' , 'QTDE'])
df
# Out:
#               DESCSERIE SEXO  QTDE
# 0       CLUBE MATEMATIC    F     1
# 1       CLUBE MATEMATIC    F     1
# 2       CLUBE MATEMATIC    F     3
# 3       CLUBE MATEMATIC    F     1
# 4       CLUBE MATEMATIC    M     1
# 5       CLUBE MATEMATIC    M     1
# 6       FLAUTA             F     1
# 7       FLAUTA             F     1
# 8       FLAUTA             F     1
# 9       FLAUTA             F     1
# 10      FLAUTA             M     1
# 11      FLAUTA             M     1
# 12      FLAUTA             M     2
# 13      FLAUTA             M     1
# 14      FLAUTA             M     1
# 15      FLAUTA             M     1
# 16      JOGOS EDUCATIVO    F     4
# 17      JOGOS EDUCATIVO    F     2
# 18      JOGOS EDUCATIVO    F     2
# 19      JOGOS EDUCATIVO    F     2
# 20      JOGOS EDUCATIVO    F     4
# 21      JOGOS EDUCATIVO    F     6
# 22      JOGOS EDUCATIVO    F    10
# 23      JOGOS EDUCATIVO    F     2
# 24      JOGOS EDUCATIVO    M     6
# 25      JOGOS EDUCATIVO    M     2
# ...

# %% [markdown]
# Assim, importamos apenas os dados relevantes para a analise que desejamos fazer.
# Com o Comando axes, o pandas ira nos indicar algumas informacoes, como, quantas linhas tem nosso dataFrame, neste caso, 346861 e quais sao as colunas que importamos, que neste caso sao DESCSERIE, que indica a descricao da atividade, SEXO, que indica se o grupo e feminino ou masculino e QTDE que indica a quantidade de alunos do grupo respectivo.

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=346861, step=1),
#  Index(['DESCSERIE', 'SEXO', 'QTDE'], dtype='object')]

# %% [markdown]
# ## Funcao sum
#
# Utilizando a funcao sum do panda Data frame, conseguimos somar todos os valores.
# Vamos supor que desejamos descobrir quantos alunos participam da atividade "CLUBE MATEMATIC".
#
# Para isso, vamos criar uma variavel chamada mathClub.
# Vamos atribuir a ela a soma das QTDE, de todas as linhas que tiveram "CLUBE MATEMATIC" como descricao da serie.
# Para isso, escrevemos:

# %%
mathClub = df[df["DESCSERIE"]=='CLUBE MATEMATIC'].sum()["QTDE"]
mathClub
# Out:
# 2963

# %% [markdown]
# Assim, conseguimos obter o valor total de matriculados em "CLUBE MATEMATIC". Se, no codigo acima, trocarmos "CLUBE MATEMATIC" por outro argumento, seremos capazes de descobrir as quantidades de qualquer outra atividade que conste em nosso csv.

# %% [markdown]
# ## Criando uma pivot table
#
# Vamos agora usar a funcao [pivot_table](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.pivot_table.html) para criar uma tabela.
#
# Vamos criar uma tabela que, agrupa todas as quantidades de meninas(F) e meninos(M), indexa pela descricao da atividade(DESCSERIE).
#
# Para tal, iremos criar uma variavel pivotSexo e chamar pivot_table sobre nosso dataframe df.

# %%
pivotSexo = df.pivot_table(index = 'DESCSERIE', columns = 'SEXO', aggfunc=sum)
print(pivotSexo)
# Out:
#                     QTDE
# SEXO                   F        M
# DESCSERIE
#  INF II ESP FI      11.0     24.0
# 1A.C.NORMAL         42.0      4.0
# 1A.SER.E.M.        522.0    566.0
# 1ª EJA MODULAR     233.0    167.0
# 2A.C.NORMAL         27.0      NaN
# 2A.SER.E.M.        585.0    533.0
# 2ª EJA MODULAR     388.0    205.0
# 3A.C.NORMAL         24.0      1.0
# 3A.SER E.M         519.0    500.0
# 3ª EJA MODULAR     781.0    581.0
# 4A.C.NORMAL         25.0      3.0
# 4ª EJA MODULAR    1118.0    972.0
# AC EST LETRAS     1391.0    629.0
# ACOLHIMENTO PRO      8.0      6.0
# ACOMP PED ORIEN     86.0     91.0
# ACOMP PEDAG POR   2594.0   3220.0
# ACOMP_CLUBE DA    1421.0   1136.0
# ALFABETIZACAO      332.0    420.0
# ALIMENTACAO         29.0     15.0
# ALONGAMENTO       1910.0    162.0
# ALUNO MONITOR      819.0    763.0
# ALUNO MONITOR D     19.0     11.0
# ALUNO MONITOR L    315.0    200.0
# ART CEN            224.0    143.0
# ART CEN  - CONT    122.0      9.0
# ...

# %% [markdown]
# Assim, obtivemos uma tabela com as atividades ordenadas em ordem alfabeticas e com duas colunas, que indicam as quantidades de pessoas do sexo feminino e masculino que participam de tal atividade.
#
# Vamos supor agora, que desejamos obter informacoes apenas sobre uma atividade. Por exemplo, CLUBE MATEMATIC. podemos usar o [loc](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html) para acessar a informacao que desejamos:

# %%
mathClubSexo = pivotSexo.loc['CLUBE MATEMATIC']
print(mathClubSexo)
# Out:
#       SEXO
# QTDE  F       1362.0
#       M       1601.0
# Name: CLUBE MATEMATIC, dtype: float64

# %%
violin = pivotSexo.loc['VIOLINO/VIOLA P']
print(violin['QTDE'])
# Out:
# SEXO
# F    233.0
# M    161.0
# Name: VIOLINO/VIOLA P, dtype: float64

# %% [markdown]
# Repare ainda, que, apesar de estarmos acessando informacoes contidas na pivot table que criamos, ela ainda esta intacta e podemos acessa-la novamente, e ela continua contendo as mesmas informacoes de antes:

# %%
print(pivotSexo)
# Out:
#                     QTDE
# SEXO                   F        M
# DESCSERIE
#  INF II ESP FI      11.0     24.0
# 1A.C.NORMAL         42.0      4.0
# 1A.SER.E.M.        522.0    566.0
# 1ª EJA MODULAR     233.0    167.0
# 2A.C.NORMAL         27.0      NaN
# 2A.SER.E.M.        585.0    533.0
# 2ª EJA MODULAR     388.0    205.0
# 3A.C.NORMAL         24.0      1.0
# 3A.SER E.M         519.0    500.0
# 3ª EJA MODULAR     781.0    581.0
# 4A.C.NORMAL         25.0      3.0
# 4ª EJA MODULAR    1118.0    972.0
# AC EST LETRAS     1391.0    629.0
# ACOLHIMENTO PRO      8.0      6.0
# ACOMP PED ORIEN     86.0     91.0
# ACOMP PEDAG POR   2594.0   3220.0
# ACOMP_CLUBE DA    1421.0   1136.0
# ALFABETIZACAO      332.0    420.0
# ALIMENTACAO         29.0     15.0
# ALONGAMENTO       1910.0    162.0
# ALUNO MONITOR      819.0    763.0
# ALUNO MONITOR D     19.0     11.0
# ALUNO MONITOR L    315.0    200.0
# ART CEN            224.0    143.0
# ART CEN  - CONT    122.0      9.0
# ...

# %% [markdown]
# ### Explorando niveis da Pivot Table
#
# A tabela que criamos anteriormente e multinivel.
#
# Podemos explorar seus niveis, indicando quais niveis queremos explorar.
#
# Por exemplo, suponha que queremos apenas ver a quantidade de meninas. Podemos fazer isso da seguinte forma:

# %%
print(pivotSexo['QTDE']['F'])
# Out:
# DESCSERIE
#  INF II ESP FI        11.0
# 1A.C.NORMAL           42.0
# 1A.SER.E.M.          522.0
# 1ª EJA MODULAR       233.0
# 2A.C.NORMAL           27.0
# 2A.SER.E.M.          585.0
# 2ª EJA MODULAR       388.0
# 3A.C.NORMAL           24.0
# 3A.SER E.M           519.0
# 3ª EJA MODULAR       781.0
# 4A.C.NORMAL           25.0
# 4ª EJA MODULAR      1118.0
# AC EST LETRAS       1391.0
# ACOLHIMENTO PRO        8.0
# ACOMP PED ORIEN       86.0
# ACOMP PEDAG POR     2594.0
# ACOMP_CLUBE DA      1421.0
# ALFABETIZACAO        332.0
# ALIMENTACAO           29.0
# ALONGAMENTO         1910.0
# ALUNO MONITOR        819.0
# ALUNO MONITOR D       19.0
# ALUNO MONITOR L      315.0
# ART CEN              224.0
# ART CEN  - CONT      122.0
# ART CEN -  VOCA      104.0
# ART CEN - ACROB       17.0
# ART CEN - AEL        663.0
# ART CEN - AFROM      194.0
# ART CEN - BALLE     1949.0
#                     ...
# REC PAR MAT M E     3966.0
# REC PAR MATEMAT     9155.0
# REC PAR PORTUGU    16598.0
# ...

# %% [markdown]
# Assim, foram impressos apenas os valores de 'F' do vetor de 'QTDE'. Isso sera util para a proxima tarefa que desejamos realizar.

# %% [markdown]
# ### MAX e IDMAX
#
# Suponha agora que desejamos descobrir quais atividades tem a maior diferenca entre meninos e meninas inscritos?
# Temos duas funcoes muito uteis, [idmax](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.idxmax.html) e [max](https://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.max.html).
#
# IDMAX retorna o indice com maior valor. No nosso caso, iremos usa-la para retornar o nome da atividade com o maior valor definido.
#
# Ja MAX retorna o valor propriamente dito.

# %%
print("Atividade com maior diferenca absoluta entre meninos e meninas : ")
print((pivotSexo['QTDE']['M'] - pivotSexo['QTDE']['F']).idxmax())

print("\nAtividade com maior diferenca absoluta entre meninas e meninos : ")
print((pivotSexo['QTDE']['F'] - pivotSexo['QTDE']['M']).idxmax())

print("\nAtividade com maior diferenca relativa entre meninos e meninas : ")
print(((pivotSexo['QTDE']['M'] - pivotSexo['QTDE']['F'])/(pivotSexo['QTDE']['M']+pivotSexo['QTDE']['F'])).idxmax())
print("Razao de meninos para meninas : ")
print(((pivotSexo['QTDE']['M'] - pivotSexo['QTDE']['F'])/(pivotSexo['QTDE']['M']+pivotSexo['QTDE']['F'])).max())

print("\nAtividade com maior diferenca relativa entre meninas e meninos : ")
print(((pivotSexo['QTDE']['F'] - pivotSexo['QTDE']['M'])/(pivotSexo['QTDE']['M']+pivotSexo['QTDE']['F'])).idxmax())
# Out:
# Atividade com maior diferenca absoluta entre meninos e meninas :
# REC PAR PORTUGU
#
# Atividade com maior diferenca absoluta entre meninas e meninos :
# ESP -  GINASTIC
#
# Atividade com maior diferenca relativa entre meninos e meninas :
# FUT FUTSAL MASC
# Razao de meninos para meninas :
# 0.8980582524271845
#
# Atividade com maior diferenca relativa entre meninas e meninos :
# OFICINA

# %%
print(pivotSexo.sort_values(by = [('QTDE', 'F')], ascending = False))
# Out:
#                       QTDE
# SEXO                     F        M
# DESCSERIE
# MINI - GRUPO II    49427.0  52624.0
# INFANTIL II 6H     48966.0  51449.0
# INFANTIL I 6H      48478.0  50368.0
# MINI - GRUPO I     43856.0  46628.0
# BERCARIO II-10h    30425.0  32560.0
# CIII 7 ANO FND 9A  23513.0  25298.0
# CII 6 ANO FND 9A   23006.0  25577.0
# CII 5 ANO FND 9A   22814.0  23995.0
# C I 3ANO FND 9A    22799.0  24739.0
# CII 4 ANO FND 9A   22053.0  23479.0
# CIII 8 ANO FND 9A  21775.0  21986.0
# C I 2ANO FND 9A    21509.0  22753.0
# C I 1ANO FND 9A    20691.0  21677.0
# REC PAR PORTUGU    16598.0  27009.0
# BERCARIO I-10h     12245.0  13181.0
# REC PAR MATEMAT     9155.0  13251.0
# MOVA                7364.0   3303.0
# ESP -  GINASTIC     6066.0    598.0
# ART CEN - DANCA     6003.0   1697.0
# HIDROGINASTICA      5700.0    673.0
# CIII 9 ANO FND 9A   5102.0   6501.0
# EJA FINAL II 2º     4281.0   3852.0
# REC PAR MAT M E     3966.0   4989.0
# ESP - XADREZ        3563.0   5579.0
# ...

# %% [markdown]
# # Criando graficos com matplotlib
#
# O [matplotlib](https://matplotlib.org/index.html) e uma biblioteca do python muito util para criar imagens e graficos 2D.
#
# O modulo principal que iremos usar e o pyplot e iremos importa-lo, assim como fizemos com a biblioteca pandas.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Criando um grafico simples
#
# O proprio pacote pandas ja conta com funcoes embutidas para criacao de graficos.
# Usando como exemplo a nossa pivot table, e baste simples ter uma visualizacao grafica simples dos dados:

# %%
pivotSexo.plot()

# %% [markdown]
# Entretanto, podemos utilizar a biblioteca plt pra ter maior flexibilidade para criar nossos graficos.
# Vamos utilizar a variavel mathClubSexo que obtivemos anteriormente, para criar um grafico da porcentagem de meninos e meninas no clube de matematica:

# %%
print(mathClubSexo)
mathClubSexo.plot()
plt.show()
# Out:
#       SEXO
# QTDE  F       1362.0
#       M       1601.0
# Name: CLUBE MATEMATIC, dtype: float64

# %% [markdown]
# ## Grafico de pizza
# Por padrao, o grafico gerado e uma linha, que nao e muito util para o tipo de dados que queremos representar.
# Um grafico de pizza(ou pie chart, em ingles) seria mais adequado. Vamos usar o [plt.pie](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.pie.html) para criar um grafico de pizza com nossos dados:

# %%
plt.pie(mathClubSexo)
plt.show()

# %% [markdown]
# ## Adicionando detalhes
#
# O grafico ainda esta muito cru e com poucas informacoes. Vamos melhora-lo, colocando labels que indicam a que dado cada setor se refere. Para isso, vamos alterar a variavel labels do nosso pie chart.
#
# Em seguida, vamos adicionar um titulo, com plt.title

# %%
plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'])
plt.show()

# %%
plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'])
plt.title('Clube de Matematica') #adicionando o título
plt.show()

# %% [markdown]
# O plt.pie tem diversos atributos que podemos alterar, customizando muito o visual do nosso grafico. Por exemplo, podemos passar um vetor com cores, para determinar exatamente as cores que queremos em cada setor.

# %%
plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'], colors = ['red', 'blue'])
plt.title('Clube de Matematica') #adicionando o título
plt.show()

# %% [markdown]
# O plt ja conta com alguns estilos padrao.

# %%
plt.style.available
# Out:
# ['seaborn-pastel',
#  'Solarize_Light2',
#  'seaborn-talk',
#  'seaborn-colorblind',
#  'seaborn',
#  'seaborn-dark-palette',
#  'ggplot',
#  'dark_background',
#  'seaborn-whitegrid',
#  'seaborn-muted',
#  'seaborn-deep',
#  '_classic_test',
#  'seaborn-dark',
#  'seaborn-bright',
#  'fast',
#  'seaborn-poster',
#  'tableau-colorblind10',
#  'seaborn-darkgrid',
#  'bmh',
#  'fivethirtyeight',
#  'seaborn-ticks',
#  'seaborn-notebook',
#  'classic',
#  'seaborn-white',
#  'seaborn-paper',
#  'grayscale']

# %% [markdown]
# Vamos escolher o estilo seaborn-colorblind, que e um estilo amigavel para pessoas com daltonismo. Assim, todos os graficos que criarmos depois desta celula seguira esse mesmo padrao.

# %%
plt.style.use('seaborn-colorblind')

# %%
plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'], autopct='%1.1f%%',
                               startangle=90, explode = [0.0, 0.01])
plt.axis('equal') #Fazer o grafico ser um circulo perfeito
plt.title('Clube de Matematica') #adicionando o título
plt.show()

# %%
plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'], autopct='%1.1f%%',
                               startangle=90, explode = [0.0, 0.1], shadow = True)
plt.axis('equal') #Fazer o grafico ser um circulo perfeito
plt.title('Clube de Matematica') #adicionando o título
plt.show()

# %%
plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'], autopct='%1.1f%%',
                               startangle=90, explode = [0.0, 0.01])
plt.axis('equal') #Fazer o grafico ser um circulo perfeito
plt.title('Clube de Matematica', fontsize = 'x-large') #adicionando o título
plt.show()

# %%
fig = plt.pie(mathClubSexo, labels = ['Meninas', 'Meninos'], autopct='%1.f%%',
                               startangle=90, explode = [0.0, 0.05])
plt.axis('equal') #Fazer o grafico ser um circulo perfeito
plt.title('Clube de Matematica', fontsize = 'x-large') #adicionando o 
patches, texts, autotexts = fig
plt.setp(autotexts, size='x-large', color = 'w', weight = 'bold')
plt.savefig('Exemplos/Clube de Matematica.png', dpi = 300)

# %% [markdown]
# ## Grafico de Barras
#
# Outro tipo bastante utilizado de grafico e o grafico de barras.
#
# Vamos coletar alguns dados da [Demanda por Vagas - Educação Infantil e EJA
# Serie historica da demanda por vagas](http://dados.prefeitura.sp.gov.br/dataset/demanda-por-vagas-educacao-infantil-e-eja)
#
# Primeiro, vamos importar o csv para um dataframe do pandas.

# %%
df = pd.read_csv('evolucaodemanda.csv' , 
                 sep = ";", encoding = 'latin-1', header = 0)

# %% [markdown]
# Vamos supor que a serie historica de interesse e a referente ao distrito de Agua Rasa.Vamos fazer um corte de nosso Dataframe, para selecionar apenas as linhas referentes a Agua Rasa:

# %%
aguaRasa = df.loc[df['DISTRITO'] == 'AGUA RASA']
aguaRasa = aguaRasa.reset_index(drop=True)

aguaRasa
# Out:
#      DISTRITO  MAT_CRECHE  MAT_PRE_ESCOLA  MAT_FUND_I  MAT_FUND_II  MAT_EJA_I  \
# 0   AGUA RASA     573.000           1.929       1.344        1.376      219.0
# 1   AGUA RASA     626.000           1.971       1.373        1.360      107.0
# 2   AGUA RASA     634.000           1.950       1.323        1.354      100.0
# 3   AGUA RASA     654.000           1.868       1.377        1.434       59.0
# 4   AGUA RASA     662.000           1.839       1.332        1.419       52.0
# 5   AGUA RASA     659.000           1.825       1.322        1.397       58.0
# 6   AGUA RASA     723.000           1.844       1.317        1.384       40.0
# 7   AGUA RASA     722.000           1.428       1.248        1.414       78.0
# 8   AGUA RASA     772.000           1.445       1.251        1.391       78.0
# 9   AGUA RASA     777.000           1.472       1.248        1.374       79.0
# 10  AGUA RASA     767.000           1.461       1.230        1.358       58.0
# ...

# %% [markdown]
# Vamos criar agora um grafico de barra, mostrando as matriculas relativa a cada uma das categorias, no ultimo periodo que temos dados, dezembro de 2017:

# %%
aguaRasa2017 = aguaRasa.loc[46]
aguaRasa2017
# Out:
# DISTRITO            AGUA RASA
# MAT_CRECHE               1045
# MAT_PRE_ESCOLA            866
# MAT_FUND_I               1047
# MAT_FUND_II               745
# MAT_EJA_I                  12
# MAT_EJA_II                 78
# MAT_ENS_MED                 0
# MAT_ED_PROF                 0
# MAT_PROC_CRECHE             0
# MAT_PROC_PRE_ESC            0
# DEM_CRECHE                102
# DEM_PRE                     0
# DEM_FUND_I                  0
# DEM_FUND_II                 0
# DEM_EJA_I                   0
# DEM_EJA_II                  0
# DEM_PREF_CRECHE           NaN
# DEM_PREF_PRE              NaN
# MES_ANO_REF            dez-17
# Name: 46, dtype: object

# %% [markdown]
# Isso ja esta bem proximo do que desejamos, mas ainda temos algumas linhas que nao queremos que aparecams, as que tem zero e as que tem NaN([not a number](https://pt.wikipedia.org/wiki/NaN)) e as que tem DEM_, ja que estamos avaliando apenas as matriculas.

# %%
aguaRasa2017 = aguaRasa2017[(aguaRasa2017!=0)].dropna().drop(['DEM_CRECHE'])

aguaRasa2017
# Out:
# DISTRITO          AGUA RASA
# MAT_CRECHE             1045
# MAT_PRE_ESCOLA          866
# MAT_FUND_I             1047
# MAT_FUND_II             745
# MAT_EJA_I                12
# MAT_EJA_II               78
# MES_ANO_REF          dez-17
# Name: 46, dtype: object

# %% [markdown]
# Pronto, agora nossa tabela conta apenas com valores validos.
#
# Vamos agora criar um grafico a partir dessa tabela.

# %%
import numpy as np

#Criar um vetor de indices
ind = np.arange(len(aguaRasa2017.index[1:-1]))
#Largura das barras
width = 0.35  

fig, ax = plt.subplots()
rects1 = ax.bar(ind,height = aguaRasa2017.values[1:-1], color='SkyBlue')

ax.set_ylabel('Matriculas')
ax.set_title('Matriculas Agua Rasa 2017')
ax.set_xticks(ind)
ax.set_xticklabels(aguaRasa2017.index[1:-1], rotation = 45, ha = 'right')
plt.savefig('Exemplos/Matriculas Agua Rasa 2017.png', dpi = 300, bbox_inches='tight')



plt.show()

# %% [markdown]
# ### Serie historica da Demanda
#
# Agora que conseguimos visualizar a demanda em 2017, podemos criar um grafico com a demanda total de agua rasa ao longo dos anos.
#
# Vamos primeiro visualizar novamente os dados que temos na variavel agua rasa:

# %%
aguaRasa
# Out:
#      DISTRITO  MAT_CRECHE  MAT_PRE_ESCOLA  MAT_FUND_I  MAT_FUND_II  MAT_EJA_I  \
# 0   AGUA RASA     573.000           1.929       1.344        1.376      219.0
# 1   AGUA RASA     626.000           1.971       1.373        1.360      107.0
# 2   AGUA RASA     634.000           1.950       1.323        1.354      100.0
# 3   AGUA RASA     654.000           1.868       1.377        1.434       59.0
# 4   AGUA RASA     662.000           1.839       1.332        1.419       52.0
# 5   AGUA RASA     659.000           1.825       1.322        1.397       58.0
# 6   AGUA RASA     723.000           1.844       1.317        1.384       40.0
# 7   AGUA RASA     722.000           1.428       1.248        1.414       78.0
# 8   AGUA RASA     772.000           1.445       1.251        1.391       78.0
# 9   AGUA RASA     777.000           1.472       1.248        1.374       79.0
# 10  AGUA RASA     767.000           1.461       1.230        1.358       58.0
# ...

# %% [markdown]
# ### Usando Regex
#
# Na coluna "MES_ANO_REF", temos valores que misturam palavras e numeros, que sao mais dificeis de trabalhar. Para isso, vamos usar str.replace junto com uma [expressao regular](https://pt.wikipedia.org/wiki/Express%C3%A3o_regular) para remover todos os caracteres que nao sao numeros dessa coluna.

# %%
pat = '([a-zA-Z])*\-'
aguaRasa.MES_ANO_REF = aguaRasa.MES_ANO_REF.str.replace( pat, '' )
aguaRasa
# Out:
#      DISTRITO  MAT_CRECHE  MAT_PRE_ESCOLA  MAT_FUND_I  MAT_FUND_II  MAT_EJA_I  \
# 0   AGUA RASA     573.000           1.929       1.344        1.376      219.0
# 1   AGUA RASA     626.000           1.971       1.373        1.360      107.0
# 2   AGUA RASA     634.000           1.950       1.323        1.354      100.0
# 3   AGUA RASA     654.000           1.868       1.377        1.434       59.0
# 4   AGUA RASA     662.000           1.839       1.332        1.419       52.0
# 5   AGUA RASA     659.000           1.825       1.322        1.397       58.0
# 6   AGUA RASA     723.000           1.844       1.317        1.384       40.0
# 7   AGUA RASA     722.000           1.428       1.248        1.414       78.0
# 8   AGUA RASA     772.000           1.445       1.251        1.391       78.0
# 9   AGUA RASA     777.000           1.472       1.248        1.374       79.0
# 10  AGUA RASA     767.000           1.461       1.230        1.358       58.0
# ...

# %% [markdown]
# Vamos agora remover, com Regex, todas as colunas que comecam com "MAT", ja que vamos avaliar apenas a demanda.

# %%
pat = '(^MAT)\w+'
aguaRasa.drop(list(df.filter(regex = pat)), axis = 1, inplace = True)
aguaRasa
# Out:
#      DISTRITO  DEM_CRECHE  DEM_PRE  DEM_FUND_I  DEM_FUND_II  DEM_EJA_I  \
# 0   AGUA RASA       505.0    153.0         0.0          0.0        0.0
# 1   AGUA RASA       583.0    160.0         0.0          0.0        0.0
# 2   AGUA RASA       683.0    199.0         0.0          0.0        0.0
# 3   AGUA RASA       523.0    250.0         0.0          0.0        0.0
# 4   AGUA RASA       467.0    229.0         0.0          0.0        0.0
# 5   AGUA RASA       713.0    148.0         0.0          0.0        0.0
# 6   AGUA RASA       360.0    353.0         0.0          0.0        0.0
# 7   AGUA RASA       192.0    125.0         0.0          0.0        0.0
# 8   AGUA RASA       246.0    107.0         0.0          0.0        0.0
# 9   AGUA RASA       358.0    100.0         0.0          0.0        0.0
# 10  AGUA RASA       135.0     89.0         0.0          0.0        0.0
# 11  AGUA RASA       136.0    121.0         0.0          0.0        0.0
# ...

# %% [markdown]
# Estamos Quase la! Vamos agora agrupar os anos pela sua media e verificar como foi a media da demanda.

# %%
#Criar uma lista com todas as colunas contidas em AguaRasa, exceto MES_ANO_REF
col_list= list(aguaRasa)
col_list.remove('MES_ANO_REF')

#Criar uma nova coluna Demanda, que recebe a soma das demandas daquela linha
aguaRasa['Demanda'] = aguaRasa[col_list].sum(axis=1)

#Criar um novo dataframe apenas com as colunas MES_ANO_REF e Demanda 
aguaRasaAno = aguaRasa[['MES_ANO_REF','Demanda']]
#Renomear MES_ANO_REF para Ano
aguaRasaAno = aguaRasaAno.rename(index=str, columns={"MES_ANO_REF": "Ano"})

#Agrupar as linhas por ano e o valor da demanda ser a media daquele ano
aguaRasaAno = aguaRasaAno.groupby(['Ano']).mean()


aguaRasaAno
# Out:
#      Demanda
# Ano
# 06    761.00
# 07    760.75
# 08    342.00
# 09    289.25
# 10    448.25
# 11    533.50
# 12    457.75
# 13    375.75
# 14    311.75
# 15    297.00
# 16    209.00
# 17    279.75

# %% [markdown]
# Vamos criar graficos, para facilitar a visualicao dos dados que obtivemos:

# %%
fig, ax = plt.subplots()

ax.set_ylabel('Demanda')
ax.set_xlabel('Ano')
ax.set_title('Evolucao da Demanda - Agua Rasa')
ax.plot(aguaRasaAno)


plt.savefig('Exemplos/Evolucao da Demanda - Agua Rasa 1', dpi = 300)

# %% [markdown]
# Modificando as [propriedadas da linha](https://matplotlib.org/1.4.1/users/pyplot_tutorial.html), podemos obter muitas variacoes deste mesmo grafico:

# %%
fig, ax = plt.subplots()

ax.set_ylabel('Demanda')
ax.set_xlabel('Ano')
ax.set_title('Evolucao da Demanda - Agua Rasa')
line, = ax.plot(aguaRasaAno)
plt.setp(line, color='g', linewidth=2.0, ls = 'steps')


plt.savefig('Exemplos/Evolucao da Demanda - Agua Rasa 2', dpi = 300)

# %%
fig, ax = plt.subplots()

ax.set_ylabel('Demanda')
ax.set_xlabel('Ano')
ax.set_title('Evolucao da Demanda - Agua Rasa')
line, = ax.plot(aguaRasaAno)
plt.setp(line, color='black', linewidth=2.0, ls = ':', marker = '+')
for i,j in zip(aguaRasaAno.index.values,list(aguaRasaAno['Demanda'])):
    ax.annotate(str(int(j)),xy=(i, j), color = 'r')

plt.savefig('Exemplos/Evolucao da Demanda - Agua Rasa 3', dpi = 300)
